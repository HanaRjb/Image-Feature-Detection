# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    image = Image.open(image_path)
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]
    cropped_image = image.crop((x_min, y_min, x_max+1, y_max+1))
    cropped_image.show()
    return cropped_image

def search_color_in_image1(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.60  # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 60:
        print("کلاه دارد")
    else:
        print("کلاه ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
  image = Image.open(image_path)
  pixel = image.getpixel((x, y))
  return pixel

def No_Hat(image_path,pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 152  # محدوده سطر مورد نظر را وارد کنید
    y = 56  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image1(resized_image, pixel_color)

image_path = "/content/image_035.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(110, 30), (110, 30), (139, 110), (234, 110)]   # لیست مختصات 4 پیکسل را وارد کنید
No_Hat(image_path,pixels)
# Out:
# <PIL.Image.Image image mode=RGB size=125x81 at 0x7FDB400A57E0>
# کلاه ندارد

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image2(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.95 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage < 95:
        print("صورت دارد")
    else:
        print("صورت ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Face(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 176  # محدوده سطر مورد نظر را وارد کنید
    y = 96  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image2(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_044.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =    [(205, 88), (260, 88), (209, 104), (253, 104)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Face(image_path, pixels)
# Out:
# صورت دارد

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image5(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.80 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 80:
        print("پا دارد")
    else:
        print("پا ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Leg(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 189  # محدوده سطر مورد نظر را وارد کنید
    y = 216  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image5(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_057.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(180, 175), (245, 175), (215, 232), (258, 232)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Leg(image_path, pixels)
# Out:
# پا ندارد

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image6(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.70 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 70:
        print("بدن چاپ شده")
    else:
        print("بدن چاپ نشده")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Body_Print(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 160  # محدوده سطر مورد نظر را وارد کنید
    y = 160  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image6(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_064.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(195,129), (242, 136), (187, 178), (242, 179)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Body_Print(image_path, pixels)
# Out:
# بدن چاپ نشده

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image7(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.80 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 80:
        print("دست دارد")
    else:
        print("دست ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Hand(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 162  # محدوده سطر مورد نظر را وارد کنید
    y = 118  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image7(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_071.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(134, 145), (157, 145), (136, 168), (157, 168)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Hand(image_path, pixels)
# Out:
# دست ندارد

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image8(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.70 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 70:
        print("سر دارد")
    else:
        print("سر ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Head(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 172  # محدوده سطر مورد نظر را وارد کنید
    y = 106  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image8(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_085.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(142, 56), (186, 56), (142, 85), (186, 85)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Head(image_path, pixels)
# Out:
# سر دارد

# %%
from PIL import Image
import math

def resize_image_with_pixels(image_path, pixels):
    # باز کردن تصویر
    image = Image.open(image_path)

    # محاسبه مختصات حداقل و حداکثر برای محدوده مورد نظر
    x_min = min(pixels, key=lambda p: p[0])[0]
    x_max = max(pixels, key=lambda p: p[0])[0]
    y_min = min(pixels, key=lambda p: p[1])[1]
    y_max = max(pixels, key=lambda p: p[1])[1]

    # برش تصویر با محدوده مورد نظر
    cropped_image = image.crop((x_min, y_min, x_max + 1, y_max + 1))

    # نمایش تصویر برش‌خورده
    #cropped_image.show()

    return cropped_image

def search_color_in_image9(image, color):
    pixel_colors = image.getdata()
    total_pixels = len(pixel_colors)
    similarity_threshold = 0.70 # آستانه شباهت (0 تا 1)

    matching_pixels = 0

    for pixel_color in pixel_colors:
        similarity = calculate_similarity(pixel_color, color)
        if similarity >= similarity_threshold:
            matching_pixels += 1

    similarity_percentage = (matching_pixels / total_pixels) * 100

    if similarity_percentage > 70:
        print("بازو دارد")
    else:
        print("بازو ندارد")

def calculate_similarity(color1, color2):
    r1, g1, b1 = color1
    r2, g2, b2 = color2

    # محاسبه فاصله اقلیدسی بین دو رنگ
    distance = ((r2 - r1) ** 2 + (g2 - g1) ** 2 + (b2 - b1) ** 2) ** 0.5

    # محاسبه شباهت بین دو رنگ
    similarity = 1 - (distance / (255 * (3 ** 0.5)))

    return similarity

def get_pixel_color(image_path, x, y):
    image = Image.open(image_path)
    pixel = image.getpixel((x, y))
    return pixel

def No_Arm(image_path, pixels):
    path1 = "/content/image_004.jpg"  # مسیر تصویر مورد نظر را وارد کنید
    x = 205  # محدوده سطر مورد نظر را وارد کنید
    y = 134  # محدوده ستون مورد نظر را وارد کنید

    pixel_color = get_pixel_color(path1, x, y)
    resized_image = resize_image_with_pixels(image_path, pixels)
    search_color_in_image9(resized_image, pixel_color)


# مثال استفاده از تابع
image_path = "/content/image_122.jpg"  # مسیر تصویر مورد نظر را وارد کنید
pixels =  [(206, 111), (224, 111), (220, 170), (224, 170)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Arm(image_path, pixels)
# Out:
# بازو ندارد

# %%
image_path = "/content/image_095.jpg"  # مسیر تصویر مورد نظر را وارد کنید
image = Image.open(image_path)
image.show()
pixels1 =  [(160, 39), (246, 39), (154, 83), (264, 83)]   # لیست مختصات 4 پیکسل را وارد کنید
No_Hat(image_path,pixels1)

pixels2 =    [(174, 89), (223, 92), (172, 106), (223, 106)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Face(image_path, pixels2)

pixels3 =  [(155, 178), (178, 182), (149, 235), (149, 235)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Leg(image_path, pixels3)

pixels4 =  [(175,122), (204, 125), (187, 178), (195, 177)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Body_Print(image_path, pixels4)

pixels5 =  [(211, 151), (236, 154), (215, 171), (236, 171)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Hand(image_path, pixels5)

pixels6 =  [(169, 89), (225, 89), (170, 125), (225, 125)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Head(image_path, pixels6)

pixels7 =  [(206, 111), (244, 111), (220, 170), (224, 170)]  # لیست مختصات 4 پیکسل را وارد کنید
No_Arm(image_path, pixels7)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288 at 0x7FDB400A4BE0>
# کلاه دارد
# صورت دارد
# پا ندارد
# بدن چاپ شده
# دست ندارد
# سر دارد
# بازو دارد
